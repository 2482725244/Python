# %%
import matplotlib.pyplot as plt
import random
plt.rcParams['font.sans-serif']=['SimHei']
plt.rcParams['axes.unicode_minus']=False
plt.figure(figsize=(20,12),dpi=80)
x = range(60)
y_beijing = [random.randint(-20,40) for i in range(60)]
y_shanghai = [random.randint(-20,40) for i in range(60)]
plt.xticks(x[::5],[f'time:11点{i}分' for i in range(60)][::5])
plt.yticks(y[::5])
plt.plot(x,y_beijing,color='r',label='北京',linestyle='--')
plt.plot(x,y_shanghai,color='g',label='上海')
plt.legend()
plt.grid(linestyle='--',alpha=0.2)
plt.title('北京和上海十一点温度变化')
plt.xlabel('时间',color='y')
plt.ylabel('温度',color='y')
plt.savefig('plt.jpg')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
fig,axes = plt.subplots(nrows=1,ncols=2,sharex=True,sharey=False,figsize=(27,8),dpi=80)
x = range(60)
y_shanghai = [random.randint(-20,40) for i in range(60)]
y_beijing = [random.randint(-20,40) for i in range(60)]
axes[0].plot(x,y_beijing,color='r',label='北京',linestyle='-.')
axes[1].plot(x,y_shanghai,color='b',label='上海')
axes[0].set_xticks(x[::5],[f'11点{i}分' for i in range(60)][::5])
axes[0].set_xlabel('时间',color='g')
axes[0].set_ylabel('温度',color='b')
axes[0].set_title('北京温度随时间变化曲线')
axes[0].grid(linestyle='--',alpha=0.7)
axes[0].legend()
axes[1].legend()

# %%
x = [225.98, 247.07, 253.14, 457.85, 241.58, 301.01,  20.67, 288.64,
       163.56, 120.06, 207.83, 342.75, 147.9 ,  53.06, 224.72,  29.51,
        21.61, 483.21, 245.25, 399.25, 343.35]
y = [196.63, 203.88, 210.75, 372.74, 202.41, 247.61,  24.9 , 239.34,
       140.32, 104.15, 176.84, 288.23, 128.79,  49.64, 191.74,  33.1 ,
        30.74, 400.02, 205.35, 330.64, 283.45]
plt.figure(figsize=(20,8),dpi=80)
plt.scatter(x,y)
plt.show()

# %%
#柱状图
x = ['雷神3：诸神黄昏','正义联盟','东方快车谋杀案','寻梦环游记','全球风暴', '降魔传','追捕','七十七天','密战','狂兽','其它']
y = [73853,57767,22354,15969,14839,8725,8716,8318,7916,6764,52222]

plt.figure(figsize=(20,8),dpi=80)

plt.bar(x,y,color=['b','r','g','y','c','m','y','k','c','g','b'])
plt.plot(x,y)
plt.show()

# %%
# 双柱状图
x = ['雷神3：诸神黄昏','正义联盟','寻梦环游记']

y1 = [10587.6,10062.5,1275.7]
y2 = [36224.9,34479.6,11830]

plt.figure(figsize=(20,8),dpi=80)
plt.xticks([i+0.1 for i in range(len(x))],x)
plt.bar(range(len(x)),y1,width=0.2,color='r')
plt.bar([i+0.2 for i in range(len(x))],y2,width=0.2,color='y')
plt.show()

# %%
time = [131,  98, 125, 131, 124, 139, 131, 117, 128, 108, 135, 138, 131, 102, 107, 114, 119, 128, 121, 142, 127, 130, 124, 101, 110, 116, 117, 110, 128, 128, 115,  99, 136, 126, 134,  95, 138, 117, 111,78, 132, 124, 113, 150, 110, 117,  86,  95, 144, 105, 126, 130,126, 130, 126, 116, 123, 106, 112, 138, 123,  86, 101,  99, 136,123, 117, 119, 105, 137, 123, 128, 125, 104, 109, 134, 125, 127,105, 120, 107, 129, 116, 108, 132, 103, 136, 118, 102, 120, 114,105, 115, 132, 145, 119, 121, 112, 139, 125, 138, 109, 132, 134,156, 106, 117, 127, 144, 139, 139, 119, 140,  83, 110, 102,123,107, 143, 115, 136, 118, 139, 123, 112, 118, 125, 109, 119, 133,112, 114, 122, 109, 106, 123, 116, 131, 127, 115, 118, 112, 135,115, 146, 137, 116, 103, 144,  83, 123, 111, 110, 111, 100, 154,136, 100, 118, 119, 133, 134, 106, 129, 126, 110, 111, 109, 141,120, 117, 106, 149, 122, 122, 110, 118, 127, 121, 114, 125, 126,114, 140, 103, 130, 141, 117, 106, 114, 121, 114, 133, 137,  92,121, 112, 146,  97, 137, 105,  98, 117, 112,  81,  97, 139, 113,134, 106, 144, 110, 137, 137, 111, 104, 117, 100, 111, 101, 110,105, 129, 137, 112, 120, 113, 133, 112,  83,  94, 146, 133, 101,131, 116, 111,  84, 137, 115, 122, 106, 144, 109, 123, 116, 111,111, 133, 150]
zuju = 2
zushu = (max(time) - min(time)) // zuju
plt.figure(figsize=(20,8),dpi = 80)
plt.hist(time,zushu,density=True)
plt.xticks(range(min(time),max(time)+2,2))
plt.show()

# %%
x = ['雷神3：诸神黄昏','正义联盟','东方快车谋杀案','寻梦环游记','全球风暴','降魔传','追捕','七十七天','密战','狂兽','其它']

y = [60605,54546,45819,28243,13270,9945,7679,6799,6101,4621,20105]
plt.figure(figsize = (20,8),dpi = 80)
plt.pie(y,labels = x,colors=['b','r','g','y','c','m','y','k','c','g','y'],autopct='%1.2f%%')
plt.legend()
plt.axis('equal')
plt.show()

# %%
import numpy as np
import random
arr = [random.randint(1,100) for i in range(60)]
nd_arr = np.array(arr)
print(nd_arr)
# Out:
# [23 12 49 18 55  2 97 31  1 72 55 49 44 23 96  6 37 77 29 78 63 44 42 33
#  57 33 72  3 60 33 81 75 35 93 31 14 33 15 56  5 90 50 35 90 14 63 36 57
#  10 60 57 41 34 82 79 79 11 59  9 44]

# %%
type(nd_arr)
# Out:
# numpy.ndarray

# %%
type(arr)
# Out:
# list

# %%
import time
arr = [random.randint(1,1000) for i in range(10000000)]
nd_arr = np.array(arr)
t1 = time.time()
sum(arr)
t2 = time.time()
print(t2-t1)

t3 = time.time()
np.sum(nd_arr)
t4 = time.time()
print(t4-t3)
# Out:
# 0.09992790222167969
# 0.014561891555786133

# %%
import numpy as np
score = np.array([[80, 89, 86, 67, 79],
[78, 97, 89, 67, 81],
[90, 94, 78, 67, 74],
[91, 91, 90, 67, 69],
[76, 87, 75, 67, 86],
[70, 79, 84, 67, 84],
[94, 92, 93, 67, 64],
[86, 85, 83, 67, 80]])

# %%
print(score)
# Out:
# [[80 89 86 67 79]
#  [78 97 89 67 81]
#  [90 94 78 67 74]
#  [91 91 90 67 69]
#  [76 87 75 67 86]
#  [70 79 84 67 84]
#  [94 92 93 67 64]
#  [86 85 83 67 80]]

# %%
score.shape
# Out:
# (8, 5)

# %%
score.ndim
# Out:
# 2

# %%
score.itemsize
# Out:
# 8

# %%
score.dtype
# Out:
# dtype('int64')

# %%
data = np.array([1.1,1.2,1.3])
data.dtype
# Out:
# dtype('float64')

# %%
data = np.array([1.2,1.3],dtype = np.float32)

# %%
data.dtype
# Out:
# dtype('float32')
